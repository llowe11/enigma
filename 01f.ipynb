# %%
import numpy as np
import pandas as pd

# %%
salary_df = pd.read_csv("./datasets/01f_dataset.csv")

# %%
salary_df.info()
salary_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
import seaborn as sns

sns.regplot(x = "YearsExperience", y = "Salary", data = salary_df)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
lin_reg = LinearRegression()

X = salary_df.YearsExperience.values.reshape(-1, 1)
y = salary_df.Salary

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=667)
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
experience = int(input("enter your expreience in years"))
f = np.array([[experience]])
predicted_salary = lin_reg.predict(f)
for i in predicted_salary:
    print(round(i, 2))
# Out:
# 120959.45
